# %%
import pandas as pd
import numpy as np

#this is made by Suvan Kumar for codesoft for b35 batch
df = pd.read_csv("/kaggle/input/advertising-dataset/advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(3, figsize=(5,5))
plt1 = sns.boxplot(df['TV'], ax=axs[0], orient='h')
plt2 = sns.boxplot(df['Radio'], ax=axs[1], orient='h')
plt2 = sns.boxplot(df['Newspaper'], ax=axs[2], orient='h')
plt.tight_layout()

# %%
fig = plt.plot(figsize=(15,5))
sns.boxplot(df['Sales'], orient='h')
plt.show()

# %%
sns.scatterplot(data=df, x='TV', y="Sales")
plt.title("Nuber of TV vs Sales")
plt.show()

# %%
sns.scatterplot(data=df, x='Radio', y="Sales")
plt.title("Nuber of Radio vs Sales")
plt.show()

# %%
sns.scatterplot(data=df, x='Newspaper', y="Sales")
plt.title("Nuber of Newspaper vs Sales")
plt.show()

# %%
X = df.drop(columns='Sales')
y = df['Sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBR

model = GBR()
GBR_Model = model.fit(X_train,y_train)

y_pred = GBR_Model.predict(X_test)

print("R2 Score: ", r2_score(y_test,y_pred))
# Out:
# R2 Score:  0.9635281614410129
